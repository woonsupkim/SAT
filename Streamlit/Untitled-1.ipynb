# %%
import pandas as pd
from PIL import Image
import base64
from io import BytesIO
import os

# %%
data = pd.read_csv('SAT_Question_Bank_Results.csv')
df = pd.read_pickle('images_dataframe.pkl')

# %%
# Function to convert base64 string to image
def base64_to_image(base64_string):
    img_data = base64.b64decode(base64_string)
    img = Image.open(BytesIO(img_data))
    return img

# %%
# Directory to save recreated images (optional)
recreate_dir = 'question_images/'
os.makedirs(recreate_dir, exist_ok=True)

# Iterate over the DataFrame and recreate the images
for index, row in df.iterrows():
    base64_str = row['Question Image2']
    if base64_str:  # Check if the base64 string is not empty
        img = base64_to_image(base64_str)
        img.save(os.path.join(recreate_dir, f'recreated_image_{index}.png'))

# %%
# Directory to save recreated images (optional)
recreate_dir = 'rationale_images/'
os.makedirs(recreate_dir, exist_ok=True)

# Iterate over the DataFrame and recreate the images
for index, row in df.iterrows():
    base64_str = row['Rationale Image2']
    if base64_str:  # Check if the base64 string is not empty
        img = base64_to_image(base64_str)
        img.save(os.path.join(recreate_dir, f'recreated_image_{index}.png'))

# %% [markdown]
# # prompt user for an answer
# - record the answer on the dataframe
# - collect how much time it took to answer the question
# - calculate if the answer is correct
# - update dataframe
# - run the model and suggest next question

# %%
img = base64_to_image(df['Question Image2'][0])
img.show()

# %%
pip install flask
# Out:
# Collecting flask
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting Werkzeug>=3.0.0 (from flask)
#   Downloading werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting Jinja2>=3.1.2 (from flask)
#   Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting itsdangerous>=2.1.2 (from flask)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting click>=8.1.3 (from flask)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting blinker>=1.6.2 (from flask)
#   Downloading blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: colorama in c:\users\woon\desktop\columbia\applied analytics\term3\projects\personal\sat\.venv\lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Collecting MarkupSafe>=2.0 (from Jinja2>=3.1.2->flask)
#   Downloading MarkupSafe-2.1.5-cp310-cp310-win_amd64.whl.metadata (3.1 kB)
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
#    ---------------------------------------- 0.0/101.7 kB ? eta -:--:--
#    ---------------------------------------- 101.7/101.7 kB 5.7 MB/s eta 0:00:00
# Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ---------------------------------------- 0.0/97.9 kB ? eta -:--:--
#    ---------------------------------------- 97.9/97.9 kB ? eta 0:00:00
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#    ---------------------------------------- 0.0/133.3 kB ? eta -:--:--
#    ---------------------------------------- 133.3/133.3 kB 7.7 MB/s eta 0:00:00
# Downloading werkzeug-3.0.3-py3-none-any.whl (227 kB)
#    ---------------------------------------- 0.0/227.3 kB ? eta -:--:--
#    --------------------------------------- 227.3/227.3 kB 13.6 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.5-cp310-cp310-win_amd64.whl (17 kB)
# Installing collected packages: MarkupSafe, itsdangerous, click, blinker, Werkzeug, Jinja2, flask
# Successfully installed Jinja2-3.1.4 MarkupSafe-2.1.5 Werkzeug-3.0.3 blinker-1.8.2 click-8.1.7 flask-3.0.3 itsdangerous-2.2.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
